# %% [markdown]
# **Correlation/Confusion Matrix - PEC 2**

# %% [markdown]
# Sleep Health and Lifestyle Dataset. (2023, September 18). Retrieved from https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv").drop(columns=['Person ID'])

corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Sleep Correlation Matrix")
plt.show()
